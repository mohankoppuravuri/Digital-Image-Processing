# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

actual = cv2.imread(r'C:\Users\Student\Desktop\Test_Images\Lena.tiff')
arr = cv2.cvtColor(actual, cv2.COLOR_BGR2GRAY)

arr0=arr.copy()

for i in range(512):
    for j in range(512):

        arr[i,j]=arr[i,j]//2
arr1=arr.copy()

for i in range(512):
    for j in range(512):

        arr[i,j]=arr[i,j]//2

arr2=arr.copy()

for i in range(512):
    for j in range(512):

        arr[i,j]=arr[i,j]//2

arr3=arr.copy()

for i in range(512):
    for j in range(512):

        arr[i,j]=arr[i,j]//2

arr4=arr.copy()

for i in range(512):
    for j in range(512):

        arr[i,j]=arr[i,j]//2

arr5=arr.copy()

for i in range(512):
    for j in range(512):

        arr[i,j]=arr[i,j]//2

arr6=arr.copy()

for i in range(512):
    for j in range(512):

        arr[i,j]=arr[i,j]//2

arr7=arr.copy()

# %%
fig=plt.figure(figsize=(16,16))


ax1=fig.add_subplot(2,4,1)
ax1.imshow(arr0,cmap='gray')
ax1.axis('off')

ax2=fig.add_subplot(2,4,2)
ax2.imshow(arr1,cmap='gray')
ax2.axis('off')

ax3=fig.add_subplot(2,4,3)
ax3.imshow(arr2,cmap='gray')
ax3.axis('off')

ax4=fig.add_subplot(2,4,4)
ax4.imshow(arr3,cmap='gray')
ax4.axis('off')

ax5=fig.add_subplot(2,4,5)
ax5.imshow(arr4,cmap='gray')
ax5.axis('off')

ax6=fig.add_subplot(2,4,6)
ax6.imshow(arr5,cmap='gray')
ax6.axis('off')

ax7=fig.add_subplot(2,4,7)
ax7.imshow(arr6,cmap='gray')
ax7.axis('off')

ax8=fig.add_subplot(2,4,8)
ax8.imshow(arr7,cmap='gray')
ax8.axis('off')


plt.subplots_adjust(wspace=0.01, hspace=-0.65)
plt.show()

# %%
fig=plt.figure(figsize=(16,16))


ax1=fig.add_subplot(2,4,1)
ax1.hist(arr0.ravel(),bins =256)


ax2=fig.add_subplot(2,4,2)
ax2.hist(arr1.ravel(),bins =256)


ax3=fig.add_subplot(2,4,3)
ax3.hist(arr2.ravel(),bins =256)


ax4=fig.add_subplot(2,4,4)
ax4.hist(arr3.ravel(),bins =256)


ax5=fig.add_subplot(2,4,5)
ax5.hist(arr4.ravel(),bins =256)



ax6=fig.add_subplot(2,4,6)
ax6.hist(arr5.ravel(),bins =256)


ax7=fig.add_subplot(2,4,7)
ax7.hist(arr6.ravel(),bins =256)


ax8=fig.add_subplot(2,4,8)
ax8.hist(arr.ravel(),bins =256)


#plt.subplots_adjust(wspace=0.01, hspace=-0.65)
plt.show()
